# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import yfinance as yf

# %%
pip install nsepy
# Out:
# Collecting nsepy
#   Downloading nsepy-0.8.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: beautifulsoup4 in c:\users\opvv1\anaconda3\lib\site-packages (from nsepy) (4.12.2)
# Requirement already satisfied: requests in c:\users\opvv1\anaconda3\lib\site-packages (from nsepy) (2.31.0)
# Requirement already satisfied: numpy in c:\users\opvv1\anaconda3\lib\site-packages (from nsepy) (1.24.3)
# Requirement already satisfied: pandas in c:\users\opvv1\anaconda3\lib\site-packages (from nsepy) (1.5.3)
# Requirement already satisfied: six in c:\users\opvv1\anaconda3\lib\site-packages (from nsepy) (1.16.0)
# Requirement already satisfied: click in c:\users\opvv1\anaconda3\lib\site-packages (from nsepy) (8.0.4)
# Requirement already satisfied: lxml in c:\users\opvv1\anaconda3\lib\site-packages (from nsepy) (4.9.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\opvv1\anaconda3\lib\site-packages (from beautifulsoup4->nsepy) (2.4)
# Requirement already satisfied: colorama in c:\users\opvv1\anaconda3\lib\site-packages (from click->nsepy) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\opvv1\anaconda3\lib\site-packages (from pandas->nsepy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\opvv1\anaconda3\lib\site-packages (from pandas->nsepy) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\opvv1\anaconda3\lib\site-packages (from requests->nsepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\opvv1\anaconda3\lib\site-packages (from requests->nsepy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\opvv1\anaconda3\lib\site-packages (from requests->nsepy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\opvv1\anaconda3\lib\site-packages (from requests->nsepy) (2023.7.22)
# Building wheels for collected packages: nsepy
#   Building wheel for nsepy (setup.py): started
#   Building wheel for nsepy (setup.py): finished with status 'done'
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36067 sha256=701ee6719edab12290866a090579e8c0f5863c0eb742736fe84cfd551113a4a7
#   Stored in directory: c:\users\opvv1\appdata\local\pip\cache\wheels\94\a7\d4\0e4e94292f5761407472684b2cd74771e9985af72f968101e0
# Successfully built nsepy
# Installing collected packages: nsepy
# Successfully installed nsepy-0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import nsepy as nse
import datetime
from datetime import date

# %%
symbol = ['PEP','KO','SBUX','AAPL','TSLA','GM','F','EBAY','NKE','UAA']
start = '2022-01-01'
end = '2023-01-01'
dataset = yf.download(symbol,start,end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BAJA']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %%
df=dataset.Close
df.head()
# Out:
#                   AAPL       EBAY          F         GM         KO  \
# Date
# 2022-01-03  182.009995  66.800003  21.770000  61.169998  59.299999
# 2022-01-04  179.699997  65.139999  24.309999  65.739998  60.290001
# 2022-01-05  174.919998  64.489998  23.660000  62.740002  60.790001
# 2022-01-06  172.000000  66.809998  24.459999  62.869999  60.470001
# 2022-01-07  172.169998  66.320000  24.440001  62.270000  60.330002
#
#                    NKE         PEP        SBUX        TSLA        UAA
# Date
# 2022-01-03  164.669998  172.979996  116.680000  399.926666  21.240000
# 2022-01-04  166.389999  173.229996  114.239998  383.196655  21.480000
# 2022-01-05  162.250000  173.820007  110.440002  362.706665  20.709999
# 2022-01-06  161.039993  173.860001  111.139999  354.899994  20.830000
# 2022-01-07  156.970001  174.080002  107.570000  342.320007  19.850000

# %%
df = df.pct_change()

# %%
df.head()
# Out:
#                 AAPL      EBAY         F        GM        KO       NKE  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.012692 -0.024850  0.116674  0.074710  0.016695  0.010445
# 2022-01-05 -0.026600 -0.009979 -0.026738 -0.045634  0.008293 -0.024881
# 2022-01-06 -0.016693  0.035975  0.033812  0.002072 -0.005264 -0.007458
# 2022-01-07  0.000988 -0.007334 -0.000818 -0.009543 -0.002315 -0.025273
#
#                  PEP      SBUX      TSLA       UAA
# Date
# 2022-01-03       NaN       NaN       NaN       NaN
# 2022-01-04  0.001445 -0.020912 -0.041833  0.011299
# 2022-01-05  0.003406 -0.033263 -0.053471 -0.035847
# 2022-01-06  0.000230  0.006338 -0.021523  0.005794
# 2022-01-07  0.001265 -0.032122 -0.035447 -0.047048

# %%
sd=df[1:]
sd.head()
# Out:
#                 AAPL      EBAY         F        GM        KO       NKE  \
# Date
# 2022-01-04 -0.012692 -0.024850  0.116674  0.074710  0.016695  0.010445
# 2022-01-05 -0.026600 -0.009979 -0.026738 -0.045634  0.008293 -0.024881
# 2022-01-06 -0.016693  0.035975  0.033812  0.002072 -0.005264 -0.007458
# 2022-01-07  0.000988 -0.007334 -0.000818 -0.009543 -0.002315 -0.025273
# 2022-01-10  0.000116 -0.026387 -0.024141 -0.019271  0.001658 -0.041600
#
#                  PEP      SBUX      TSLA       UAA
# Date
# 2022-01-04  0.001445 -0.020912 -0.041833  0.011299
# 2022-01-05  0.003406 -0.033263 -0.053471 -0.035847
# 2022-01-06  0.000230  0.006338 -0.021523  0.005794
# 2022-01-07  0.001265 -0.032122 -0.035447 -0.047048
# 2022-01-10  0.000517 -0.014316  0.030342 -0.015617

# %%
from sklearn.decomposition import PCA

num_pc = 2


X = np.asarray(sd)
[n,m] = X.shape
pca = PCA(n_components=num_pc)
pca.fit(X)
percentage =  pca.explained_variance_ratio_
percentage_cum = np.cumsum(percentage)
print('{0:.2f}% of the variance is explained by the first 2 PCs'.format(percentage_cum[-1]*100))

pca_components = pca.components_
# Out:
# 74.73% of the variance is explained by the first 2 PCs

# %%
print(pca_components.T)
# Out:
# [[ 0.26386382  0.07941586]
#  [ 0.2631466   0.01856022]
#  [ 0.36631832 -0.10147531]
#  [ 0.34353256 -0.03650946]
#  [ 0.08573526 -0.06159573]
#  [ 0.32298301 -0.21412313]
#  [ 0.08201907 -0.03956918]
#  [ 0.24853719 -0.02392086]
#  [ 0.46299538  0.78804385]
#  [ 0.46302794 -0.55580993]]

# %%
from sklearn.cluster import KMeans
cord=pca_components.T
data = np.array(cord)
kmeans = KMeans(n_clusters=5)
kmeans.fit(data)
labels = kmeans.labels_
clusters = {i: [] for i in range(5)}
for i in range(len(cord)):
    clusters[labels[i]].append(cord[i])
for cluster_num, points in clusters.items():
    print(f"Cluster {cluster_num + 1}: {points}")
# Out:
# Cluster 1: [array([ 0.46302794, -0.55580993])]
# Cluster 2: [array([0.46299538, 0.78804385])]
# Cluster 3: [array([0.26386382, 0.07941586]), array([0.2631466 , 0.01856022]), array([ 0.34353256, -0.03650946]), array([ 0.24853719, -0.02392086])]
# Cluster 4: [array([ 0.08573526, -0.06159573]), array([ 0.08201907, -0.03956918])]
# Cluster 5: [array([ 0.36631832, -0.10147531]), array([ 0.32298301, -0.21412313])]

# %%
plt.scatter(data[:, 0], data[:, 1])
for cluster_num, points in clusters.items():
    plt.annotate(cluster_num+1, (points[0][0], points[0][1]), textcoords="offset points", xytext=(5,5), ha='center')
labels = sd.columns
for label, x, y in zip(labels, data[:, 0], data[:, 1]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-20, 20),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0')
    );
